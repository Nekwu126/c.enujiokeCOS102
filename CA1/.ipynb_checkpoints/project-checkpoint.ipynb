# %%
from tkinter import *
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk


    
    

    
main_window = Tk()
main_window.geometry("420x420")
main_window.title("PAU Cafeteria Menu")
main_window.config(background='#d68131')

#creating the food labels
welcome_label = tk.Label(main_window, 
                         text="WELCOME TO PAU CAFETERIA",
                         font=('Comic Sans', 30),
                         bg='#d68131'
                        )
welcome_label.pack()

ricetitle_label = tk.Label(main_window,
                           text="Rice or Pasta",
                           font=('Comic Sans',20),
                           bg='#d68131'
                          )
ricetitle_label.place(x=30,y=140)
                     

riceoption_label = tk.Label(main_window,
                            text="Jollof rice      350 \nCoconut Fried Rice    350 \nJollof Spaghetti    350",
                            font=('Comic sans',10),
                            bg='#d68131'
                           )
riceoption_label.place(x=40,y=180)

sidedishtitle_label = tk.Label(main_window,
                               text="Side Dishes",
                               font=('Comic Sans',20),
                               bg='#d68131'
                         )
sidedishtitle_label.place(x=40,y=280)

sidedishoption_label = tk.Label(main_window,
                                text="Savoury Beans    350 \nRoasted Sweet Potatoes    300 \nFried Plantains    160 \nMixed Vegetable Salad    160 \nBoiled Yam    150",
                                font=('Comic Sans',10),
                                bg='#d68131')
sidedishoption_label.place(x=40,y=325)

#Soups and swallows
souptitle_label = tk.Label(main_window,
                           text="Soups and swallows",
                           font=('Comic Sans',20),
                           bg='#d68131'
                         )
souptitle_label.place(x=40,y=458)

soups_label = tk.Label(main_window,
                       text="Eba    100 \nPoundo Yam    100 \nSemo    100 \nAtama Soup    450 \nEgusi Soup    400",
                       font=('Comic Sans',10),
                       bg='#d68131'
                       )
soups_label.place(x=55,y=495)

#Proteins
proteintitle_label = tk.Label(main_window,
                              text="Proteins",
                              font=('Comic Sans',20),
                              bg='#d68131'
                         )
proteintitle_label.place(x=920,y=400)

proteins_label = tk.Label(main_window,
                          text="Sweet Chill Chicken    1000 \nGrilled Chicken Wings    400 \nFried Beef    400 \nFried Fish    500 \nBoiled Egg    200 \nSauteed Sausages    200",
                          font=('Comic Sans',10),
                          bg='#d68131'
                           )
proteins_label.place(x=900,y=440)

#Beverages
drinks_label = tk.Label(main_window,
                        text="Beverages",
                        font=('Comic Sans',20),
                        bg='#d68131'
                         )
drinks_label.place(x=900,y=80)

drinksoption_label = tk.Label(main_window,
                              text="Water    200 \nGlass Drink (15cl)    150 \nPET DRINK (15cl)    300 \nPET Drink (35cl)    350 \nFresh Yo    600 \nPineapple Juice    350 \nMango Juice    300 \nZobo Drink    350",
                              font=('Comic Sans',10),
                              bg='#d68131',
                              fg='#FFFFFF'
                              
                               )
drinksoption_label.place(x=900,y=120)

main_window.mainloop()

def order():
    order_window = tk.Toplevel(main_window)
    order_window.title("Your order")

#global name, food_item, quantity
name = tk.StringVar()
food_item = tk.StringVar()
quantity = tk.IntVar()

name_label = tk.Label(order_window,text="Name: ")
name_label.grid(row=0, column=0)
name_entry = tk.Entry(order_window,
                      textvariable=name)
name.entry.grid(row=0, column=1)

food_label = tk.Label(order_window, text="Food item:")
food_label.grid(row=1,column=0)
food_entry = tk.Entry(order_window,textvariable=food_item)
food_entry.grid(row=1,column=1)

quantity_label = tk.Label(order_window,text="Quantity:")
quantity_label.grid(row=2,column=0)
quantity_entry = tk.Entry(order_window,textvariable=quantity)
quantity_entry.grid(row=2,column=1)

submit_button = tk.Button(order_window,text="Submit",command=calculate_total)
submit_button.grid(row=3,column=0,columnspan=2)

def order_calc():
    if order < 2500:
        print("You have a 10% discount")

    elif order > 2500:
        print("You have a 15% discount")
    elif order > 5000:
        print("You have a 25% discount")
    elif order < 1000:
        print("You have no discount")

order_window.mainloop()


close_button = tk.Button(window,text="Close",command=window.destroy)
close_button.pack()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 106
#     103     order_window.title("Your order")
#     105 #global name, food_item, quantity
# --> 106 name = tk.StringVar()
#     107 food_item = tk.StringVar()
#     108 quantity = tk.IntVar()
#
# File ~\anaconda3\Lib\tkinter\__init__.py:562, in StringVar.__init__(self, master, value, name)
#     552 def __init__(self, master=None, value=None, name=None):
#     553     """Construct a string variable.
#     554
#     555     MASTER can be given as master widget.
#    (...)
#     560     then the existing value is retained.
#     561     """
# --> 562     Variable.__init__(self, master, value, name)
#
# File ~\anaconda3\Lib\tkinter\__init__.py:393, in Variable.__init__(self, master, value, name)
#     391 global _varnum
#     392 if master is None:
# --> 393     master = _get_default_root('create variable')
# ...

# %%
#CREATE the main window 
#CREATE the welcome title label
#CREATE the food title labels and the options separately
#CREATE a different window for taking orders
#CREATE labels for food, quantity and name
#CREATE a submit button
#CREATE a window to calculate the amount of money to be paid
#CREATE a function for the conditions:
#if the total order is less than 2500, print('You have a 10% discount')
#if the total order os greater than 2500 and less than 5000, print(
#'You have a 15% discount')
#if the order is greater than 5000, print('You have a 25% discount')
#else if the order is greater than 1000, the customer gets a 25% discount
#CREATE a button to close the window
