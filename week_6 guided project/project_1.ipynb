# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def welcomeMessage1(username):
    #Create a TKinter window
    window = tk.Toplevel(root)
    window.title("Simi services")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {username} \n")
    label_1.pack()
    label_2 = tk.Label(window, text="Your fee is 5000")
    label_2.pack()

def welcomeMessage2(username):
    #Create a TKinter window
    window = tk.Toplevel(root)
    window.title("Simi services")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {username} \n")
    label_1.pack()
    label_2 = tk.Label(window, text="Your fee is 3500")
    label_2.pack()

def welcomeMessage3(username):
    #Create a TKinter window
    window = tk.Toplevel(root)
    window.title("Simi services")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {username} \n")
    label_1.pack()
    label_2 = tk.Label(window, text="Your fee is 10000")
    label_2.pack()

def submit():
    username = username_entry.get()
    weight = weight_entry.get()
    location = location_entry.get()

    if weight < 10 and location == "Epe":
        welcomeMessage2(username)        
    if location == "Epe" and weight >= 10:
        welcomeMessage3(username)
    if location == "Ibeju" and weight >= 10:
        welcomeMessage1(username)
    else: 
        messagebox.showerror("U fit try again?")

#Create main window
root = tk.Tk()
root.title("Simi services with AG")
root.geometry("500x200")

#Create username label and entry
username_label = tk.Label(root, text="Username:")
username_label.pack()
username_entry = tk.Entry(root)
username_entry.pack()

# Create weight label and entry
weight_label = tk.Label(root, text="Weight(kg):")
weight_label.pack()
weight_label = tk.Entry(root)
weight_label.pack()

# Create location label and entry
location_label = tk.Label(root, text="Location:")
location_label.pack()
location_label = tk.Entry(root)
location_label.pack()

# Create submit button
submit_button = tk.Button(root, text="Press am", command=submit)
submit_button.pack()

#Run the main event loop
root.mainloop()
